# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import keras

from keras.utils import np_utils
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
)
import os
print(os.listdir("C:/Users/zakzi89/Documents/gambar/ck/"))
# Out:
# ['CK+48']

# %%
data_path = 'C:/Users/zakzi89/Documents/gambar/ck/CK+48'
data_dir_list = os.listdir(data_path)

img_rows=256
img_cols=256
num_channel=1

num_epoch=10

img_data_list=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(48,48))
        img_data_list.append(input_img_resize)

img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-disgust
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-surprise
# (981, 48, 48, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:134]=0 #135
labels[135:188]=1 #54
labels[189:365]=2 #177
labels[366:440]=3 #75
labels[441:647]=4 #207
labels[648:731]=5 #84
labels[732:980]=6 #249

names = ['anger','contempt','disgust','fear','happy','sadness','surprise']

def getLabel(id):
    return ['anger','contempt','disgust','fear','happy','sadness','surprise'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=2)
x_test=X_test

# %%
input_shape=(48,48,3)

model = Sequential()
model.add(Conv2D(6, (5, 5), input_shape=input_shape, padding='same', activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (5, 5), padding='same', activation = 'relu'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation = 'softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %%
model.summary()
model.get_config()
model.layers[0].get_config()
model.layers[0].input_shape
model.layers[0].output_shape
model.layers[0].get_weights()
np.shape(model.layers[0].get_weights()[0])
model.layers[0].trainable
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 6)         456
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 16)        2416
#
#  activation (Activation)     (None, 24, 24, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 64)        9280
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 217,983
# Trainable params: 217,983
# Non-trainable params: 0
# _________________________________________________________________
# True

# %%
hist = model.fit(X_train, y_train, batch_size=7, epochs=50, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 119/119 [==============================] - 7s 31ms/step - loss: 1.8198 - accuracy: 0.2833 - val_loss: 1.5082 - val_accuracy: 0.4392
# Epoch 2/50
# 119/119 [==============================] - 3s 29ms/step - loss: 1.2502 - accuracy: 0.5534 - val_loss: 0.8160 - val_accuracy: 0.7027
# Epoch 3/50
# 119/119 [==============================] - 3s 26ms/step - loss: 0.7810 - accuracy: 0.7263 - val_loss: 0.5566 - val_accuracy: 0.7703
# Epoch 4/50
# 119/119 [==============================] - 3s 25ms/step - loss: 0.6449 - accuracy: 0.7623 - val_loss: 0.4085 - val_accuracy: 0.9324
# Epoch 5/50
# 119/119 [==============================] - 3s 29ms/step - loss: 0.5204 - accuracy: 0.8307 - val_loss: 0.2891 - val_accuracy: 0.9189
# Epoch 6/50
# 119/119 [==============================] - 3s 27ms/step - loss: 0.3944 - accuracy: 0.8776 - val_loss: 0.2661 - val_accuracy: 0.9122
# Epoch 7/50
# 119/119 [==============================] - 3s 26ms/step - loss: 0.3115 - accuracy: 0.9088 - val_loss: 0.1512 - val_accuracy: 0.9595
# Epoch 8/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.2722 - accuracy: 0.9232 - val_loss: 0.0855 - val_accuracy: 0.9662
# Epoch 9/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.2420 - accuracy: 0.9280 - val_loss: 0.1744 - val_accuracy: 0.9324
# Epoch 10/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.1952 - accuracy: 0.9412 - val_loss: 0.0929 - val_accuracy: 0.9730
# Epoch 11/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.1548 - accuracy: 0.9580 - val_loss: 0.1957 - val_accuracy: 0.9257
# Epoch 12/50
# 119/119 [==============================] - 3s 27ms/step - loss: 0.1581 - accuracy: 0.9424 - val_loss: 0.1373 - val_accuracy: 0.9527
# Epoch 13/50
# 119/119 [==============================] - 4s 36ms/step - loss: 0.1582 - accuracy: 0.9508 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 14/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.1242 - accuracy: 0.9640 - val_loss: 0.0579 - val_accuracy: 0.9797
# Epoch 15/50
# 119/119 [==============================] - 4s 34ms/step - loss: 0.1461 - accuracy: 0.9568 - val_loss: 0.0775 - val_accuracy: 0.9797
# Epoch 16/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.1022 - accuracy: 0.9700 - val_loss: 0.0286 - val_accuracy: 0.9932
# Epoch 17/50
# 119/119 [==============================] - 4s 38ms/step - loss: 0.1080 - accuracy: 0.9700 - val_loss: 0.0465 - val_accuracy: 0.9865
# Epoch 18/50
# 119/119 [==============================] - 4s 36ms/step - loss: 0.0993 - accuracy: 0.9712 - val_loss: 0.0317 - val_accuracy: 0.9932
# Epoch 19/50
# 119/119 [==============================] - 3s 26ms/step - loss: 0.0790 - accuracy: 0.9736 - val_loss: 0.0458 - val_accuracy: 0.9865
# Epoch 20/50
# 119/119 [==============================] - 4s 33ms/step - loss: 0.1047 - accuracy: 0.9760 - val_loss: 0.0357 - val_accuracy: 0.9932
# Epoch 21/50
# 119/119 [==============================] - 5s 39ms/step - loss: 0.0491 - accuracy: 0.9844 - val_loss: 0.0884 - val_accuracy: 0.9662
# Epoch 22/50
# 119/119 [==============================] - 4s 35ms/step - loss: 0.0807 - accuracy: 0.9736 - val_loss: 0.0492 - val_accuracy: 0.9932
# Epoch 23/50
# 119/119 [==============================] - 4s 34ms/step - loss: 0.0666 - accuracy: 0.9808 - val_loss: 0.0642 - val_accuracy: 0.9730
# Epoch 24/50
# 119/119 [==============================] - 4s 34ms/step - loss: 0.0648 - accuracy: 0.9796 - val_loss: 0.0417 - val_accuracy: 0.9865
# Epoch 25/50
# 119/119 [==============================] - 4s 36ms/step - loss: 0.0873 - accuracy: 0.9652 - val_loss: 0.0903 - val_accuracy: 0.9730
# Epoch 26/50
# 119/119 [==============================] - 5s 38ms/step - loss: 0.0806 - accuracy: 0.9688 - val_loss: 0.0184 - val_accuracy: 0.9932
# Epoch 27/50
# 119/119 [==============================] - 5s 39ms/step - loss: 0.0703 - accuracy: 0.9772 - val_loss: 0.0210 - val_accuracy: 0.9932
# Epoch 28/50
# 119/119 [==============================] - 4s 37ms/step - loss: 0.0748 - accuracy: 0.9796 - val_loss: 0.0269 - val_accuracy: 0.9865
# Epoch 29/50
# 119/119 [==============================] - 5s 38ms/step - loss: 0.0669 - accuracy: 0.9748 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 30/50
# 119/119 [==============================] - 4s 38ms/step - loss: 0.0646 - accuracy: 0.9736 - val_loss: 0.0264 - val_accuracy: 0.9932
# Epoch 31/50
# 119/119 [==============================] - 4s 34ms/step - loss: 0.0595 - accuracy: 0.9784 - val_loss: 0.0333 - val_accuracy: 0.9865
# Epoch 32/50
# 119/119 [==============================] - 4s 31ms/step - loss: 0.0486 - accuracy: 0.9808 - val_loss: 0.0296 - val_accuracy: 0.9797
# Epoch 33/50
# 119/119 [==============================] - 3s 29ms/step - loss: 0.0783 - accuracy: 0.9796 - val_loss: 0.0308 - val_accuracy: 0.9932
# Epoch 34/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.0487 - accuracy: 0.9796 - val_loss: 0.0435 - val_accuracy: 0.9797
# Epoch 35/50
# 119/119 [==============================] - 4s 34ms/step - loss: 0.0416 - accuracy: 0.9832 - val_loss: 0.0533 - val_accuracy: 0.9865
# Epoch 36/50
# 119/119 [==============================] - 3s 27ms/step - loss: 0.0577 - accuracy: 0.9820 - val_loss: 0.0301 - val_accuracy: 0.9797
# Epoch 37/50
# 119/119 [==============================] - 3s 23ms/step - loss: 0.0602 - accuracy: 0.9796 - val_loss: 0.0249 - val_accuracy: 0.9932
# Epoch 38/50
# 119/119 [==============================] - 3s 25ms/step - loss: 0.0657 - accuracy: 0.9736 - val_loss: 0.0325 - val_accuracy: 0.9797
# Epoch 39/50
# 119/119 [==============================] - 3s 25ms/step - loss: 0.0786 - accuracy: 0.9736 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 40/50
# 119/119 [==============================] - 3s 21ms/step - loss: 0.0424 - accuracy: 0.9820 - val_loss: 0.0296 - val_accuracy: 0.9865
# Epoch 41/50
# 119/119 [==============================] - 3s 23ms/step - loss: 0.0501 - accuracy: 0.9856 - val_loss: 0.0700 - val_accuracy: 0.9932
# Epoch 42/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.0784 - accuracy: 0.9760 - val_loss: 0.0336 - val_accuracy: 0.9865
# Epoch 43/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.0366 - accuracy: 0.9880 - val_loss: 0.0634 - val_accuracy: 0.9797
# Epoch 44/50
# 119/119 [==============================] - 3s 29ms/step - loss: 0.0532 - accuracy: 0.9820 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 45/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.0489 - accuracy: 0.9784 - val_loss: 0.1103 - val_accuracy: 0.9865
# Epoch 46/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.0581 - accuracy: 0.9796 - val_loss: 0.0777 - val_accuracy: 0.9865
# Epoch 47/50
# 119/119 [==============================] - 3s 28ms/step - loss: 0.0675 - accuracy: 0.9748 - val_loss: 0.1381 - val_accuracy: 0.9459
# Epoch 48/50
# 119/119 [==============================] - 4s 31ms/step - loss: 0.0783 - accuracy: 0.9748 - val_loss: 0.0441 - val_accuracy: 0.9797
# Epoch 49/50
# 119/119 [==============================] - 4s 30ms/step - loss: 0.0807 - accuracy: 0.9724 - val_loss: 0.0877 - val_accuracy: 0.9730
# Epoch 50/50
# 119/119 [==============================] - 3s 22ms/step - loss: 0.0546 - accuracy: 0.9772 - val_loss: 0.0232 - val_accuracy: 0.9932

# %%
# visualizing losses and accuracy
# %matplotlib inline

train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['accuracy']
val_acc=hist.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs,train_loss,'r', label='train_loss')
plt.plot(epochs,val_loss,'b', label='val_loss')
plt.title('train_loss vs val_loss')
plt.legend()
plt.figure()

plt.plot(epochs,train_acc,'r', label='train_acc')
plt.plot(epochs,val_acc,'b', label='val_acc')
plt.title('train_acc vs val_acc')
plt.legend()
plt.figure()
